# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
uss_df = pd.read_csv('USS_Responses.csv')

# %%
uss_df.dropna()
uss_df.head()
# Out:
#             Timestamp Which age group do you belong to?  \
# 0  2/15/2025 18:46:54                 25 - 34 years old
# 1  2/15/2025 18:59:55                 18 - 24 years old
# 2  2/15/2025 19:02:50                 18 - 24 years old
# 3  2/15/2025 19:04:53                 18 - 24 years old
# 4  2/15/2025 19:58:24                 18 - 24 years old
#
#   What is your employment status? Which part of the year did you visit USS?  \
# 0                        Employed                        October - December
# 1                         Student                              April - June
# 2                         Student                   Can't recall / Not sure
# 3                         Student                        October - December
# 4                         Student                   Can't recall / Not sure
#
#    Who did you visit USS with? What was the main purpose of your visit?  \
# 0                      Friends                         Social gathering
# ...

# %%
uss_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 210 entries, 0 to 209
# Data columns (total 55 columns):
#  #   Column                                                                                                                                                        Non-Null Count  Dtype
# ---  ------                                                                                                                                                        --------------  -----
#  0   Timestamp                                                                                                                                                     210 non-null    object
#  1   Which age group do you belong to?                                                                                                                             210 non-null    object
# ...

# %%
uss_df.mean()
# Out:
# C:\Users\Keagan\AppData\Local\Temp\ipykernel_78296\1716087439.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   uss_df.mean()
# On a scale of 1-5, how would you rate your overall experience at USS?                                                                                           3.723810
# How easy was it to find relevant information about USS online (ticket pricing, attractions, events, etc.)?                                                      4.109453
# How easy was it to navigate the USS website to find information about tickets, attractions, and events?                                                         2.924812
# If you used the USS app, how would you rate its ease of use?                                                                                                    3.625000
# ...
